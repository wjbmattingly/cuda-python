# %%
# !pip install datasets huggingface-hub pandas
# Out:
# Requirement already satisfied: datasets in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: huggingface-hub in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (0.27.1)
# Requirement already satisfied: pandas in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: filelock in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (2.0.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: packaging in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from huggingface-hub) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wjbmattingly/anaconda3/envs/cuda124/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.12.14)

# %%
from datasets import load_dataset, concatenate_datasets
from huggingface_hub import list_repo_files
import pandas as pd

# %%
files = list(list_repo_files(repo_id='davanstrien/AmericanStories-parquet', repo_type='dataset'))
len(files)
# Out:
# 266

# %%
years = {
        "1938": [],
        "1939": [],
        "1940": [],
        "1941": [],
        "1942": [],
        "1943": [],
        "1944": [],
        "1945": []
         }
for year in years:
    for file in files:
        file_year = file.split('/')[-1].split("-")[0]
        if year in file_year:
            years[year].append(file)
print(years)
# Out:
# {'1938': ['data/1938-00000-of-00002-091c3285e9718147.parquet', 'data/1938-00001-of-00002-ee8604fd83ff776f.parquet'], '1939': ['data/1939-00000-of-00002-fc041e884dae3517.parquet', 'data/1939-00001-of-00002-00a4ab7e54bcd155.parquet'], '1940': ['data/1940-00000-of-00001-cc9e4c07d2868aac.parquet'], '1941': ['data/1941-00000-of-00002-90d725e865fcd277.parquet', 'data/1941-00001-of-00002-ff89c400ae6e2954.parquet'], '1942': ['data/1942-00000-of-00002-73a4a9ef208b48aa.parquet', 'data/1942-00001-of-00002-f2b2743c00a1e8b3.parquet'], '1943': ['data/1943-00000-of-00001-08d4eecdd9d63294.parquet'], '1944': ['data/1944-00000-of-00001-0898daee07832f8f.parquet'], '1945': ['data/1945-00000-of-00002-f78a1735b619bf2b.parquet', 'data/1945-00001-of-00002-eea83a5833687118.parquet']}

# %%
datasets = []
for year, files in years.items():
    dataset = load_dataset(
        "davanstrien/AmericanStories-parquet",
        data_files={year: files},
        split=year,
        verification_mode='no_checks'
    )
    datasets.append(dataset)

print(datasets)
# Out:
# [Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 665274
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 556283
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 496662
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 637200
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 523923
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 467200
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 433769
# }), Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 588477
# })]

# %%
combined_dataset = concatenate_datasets(datasets)
combined_dataset
# Out:
# Dataset({
#     features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#     num_rows: 4368788
# })

# %%
df = pd.DataFrame(combined_dataset)
df
# Out:
#                                                 article_id  \
# 0        1_1938-11-08_p3_sn82014085_00393347429_1938110...
# 1        3_1938-11-08_p3_sn82014085_00393347429_1938110...
# 2        4_1938-11-08_p3_sn82014085_00393347429_1938110...
# 3        5_1938-11-08_p3_sn82014085_00393347429_1938110...
# 4        6_1938-11-08_p3_sn82014085_00393347429_1938110...
# ...                                                    ...
# 4368783  28_1945-12-05_p7_sn88063294_00340589130_194512...
# 4368784  10_1945-04-18_p35_sn83045462_00280604082_19450...
# 4368785  3_1945-04-18_p35_sn83045462_00280604082_194504...
# 4368786  21_1945-04-18_p35_sn83045462_00280604082_19450...
# 4368787  6_1945-04-18_p35_sn83045462_00280604082_194504...
#
#                   newspaper_name edition        date page  \
# 0        The Waterbury Democrat.      01  1938-11-08   p3
# 1        The Waterbury Democrat.      01  1938-11-08   p3
# 2        The Waterbury Democrat.      01  1938-11-08   p3
# 3        The Waterbury Democrat.      01  1938-11-08   p3
# 4        The Waterbury Democrat.      01  1938-11-08   p3
# ...                          ...     ...         ...  ...
# 4368783   Detroit evening times.      01  1945-12-05   p7
# 4368784            Evening star.      01  1945-04-18  p35
# 4368785            Evening star.      01  1945-04-18  p35
# 4368786            Evening star.      01  1945-04-18  p35
# 4368787            Evening star.      01  1945-04-18  p35
#
#                                                   headline  \
# 0         Fear Heavy Toll Among Civilians In Next Conflict
# 1
# 2        Audience Thrilled By\n\n Early Masters Works\n...
# 3        Democrats Institute Court Action T oday\n\n To...
# 4        q WOMEN SEEK\n\n ELECTION JOBS\n\nNone Candida...
# ...                                                    ...
# 4368783
# 4368784  ADVERTISEMENT,\n\nADNL n lSLhLt>1\nTorment OF ...
# 4368785  Jury Rules Chaplin\nIs.Father;; Conference\nOn...
# 4368786                          Use Your\nBeIdqet Account
# 4368787                              Verdict for Defendant
#
#                                                     byline  \
# 0
# 1
# 2
# 3
# 4        BY RUBY A. BLACK nifAd preea Sfaff Corresnovad...
# ...                                                    ...
# 4368783
# 4368784
# 4368785                           By the Associated Press.
# 4368786
# 4368787
#
#                                                    article
# 0        Recognition of a probable heavy toll among non...
# 1        Conforming to tradition, the Democratic candid...
# 2        second by Kasper Ferdinand Fisch- CT.\n\n FOlk...
# 3        in behalf of Charles Maloney of Se4 East Main ...
# 4        NUnlte0 freSS Stam COrreSpOn0ent)\n\n Washingt...
# ...                                                    ...
# 4368783  Here's a contest you win! And what prize!\nA b...
# 4368784  II you can't get your feet of your mind\nbecau...
# 4368785  By the Associated Press.\n\n\nLOS ANGELES, Apr...
# 4368786  It's easy as A-B-C to open a\nCharge, Budget o...
# 4368787  A District Court jury yesterday\nreturned a ve...
#
# [4368788 rows x 8 columns]

# %%
df.to_parquet('../data/american_stories_1938_1945.parquet')
