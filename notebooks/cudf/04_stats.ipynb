# %%
import cudf

# %%
df = cudf.read_parquet('../data/american_stories_1938_1945.parquet')

# %%
# !nvidia-smi
# Out:
# Fri Feb  7 20:50:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX 5000 Ada Gene...    Off |   00000000:01:00.0 Off |                  Off |
# | 30%   32C    P2             55W /  250W |    5172MiB /  32760MiB |      7%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2098      G   /usr/lib/xorg/Xorg                            350MiB |
# |    0   N/A  N/A      2533      G   /usr/bin/gnome-shell                          189MiB |
# |    0   N/A  N/A      5538      G   ...erProcess --variations-seed-version        233MiB |
# |    0   N/A  N/A      6698      C   ...y/anaconda3/envs/cuda124/bin/python       4360MiB |
# +-----------------------------------------------------------------------------------------+

# %%
df.head(1)
# Out:
#                                           article_id           newspaper_name  \
# 0  1_1938-11-08_p3_sn82014085_00393347429_1938110...  The Waterbury Democrat.
#
#   edition        date page                                          headline  \
# 0      01  1938-11-08   p3  Fear Heavy Toll Among Civilians In Next Conflict
#
#   byline                                            article
# 0         Recognition of a probable heavy toll among non...

# %% [markdown]
# ## Creating Numeric Columns
#
# In this section, we'll create two numeric columns to help analyze our articles:
# - word_count: The number of words in each article (calculated by counting spaces + 1)
# - text_length: The total number of characters in each article
#
# We will use these columns to calculate the average word count and text length of our articles, as well as other statistics.

# %%
df['word_count'] = df['article'].str.count(' ') + 1
# Get text lengths
df['text_length'] = df['article'].str.len()

# %%
df.head(5)
# Out:
#                                           article_id           newspaper_name  \
# 0  1_1938-11-08_p3_sn82014085_00393347429_1938110...  The Waterbury Democrat.
# 1  3_1938-11-08_p3_sn82014085_00393347429_1938110...  The Waterbury Democrat.
# 2  4_1938-11-08_p3_sn82014085_00393347429_1938110...  The Waterbury Democrat.
# 3  5_1938-11-08_p3_sn82014085_00393347429_1938110...  The Waterbury Democrat.
# 4  6_1938-11-08_p3_sn82014085_00393347429_1938110...  The Waterbury Democrat.
#
#   edition        date page                                           headline  \
# 0      01  1938-11-08   p3   Fear Heavy Toll Among Civilians In Next Conflict
# 1      01  1938-11-08   p3
# 2      01  1938-11-08   p3  Audience Thrilled By\n\n Early Masters Works\n...
# 3      01  1938-11-08   p3  Democrats Institute Court Action T oday\n\n To...
# 4      01  1938-11-08   p3  q WOMEN SEEK\n\n ELECTION JOBS\n\nNone Candida...
#
#                                               byline  \
# 0
# 1
# 2
# 3
# 4  BY RUBY A. BLACK nifAd preea Sfaff Corresnovad...
#
#                                              article  word_count  text_length
# 0  Recognition of a probable heavy toll among non...         233         1506
# 1  Conforming to tradition, the Democratic candid...         256         1624
# 2  second by Kasper Ferdinand Fisch- CT.\n\n FOlk...         124          766
# 3  in behalf of Charles Maloney of Se4 East Main ...         224         1278
# 4  NUnlte0 freSS Stam COrreSpOn0ent)\n\n Washingt...         280         1746

# %% [markdown]
# ## Mean Values
#
# Looking at the mean values above:
# - The average word count is around 120 words per article
# - The average text length is around 811 characters per article
#
# This suggests that most articles in our dataset are relatively short, perhaps being news briefs or small updates rather than long-form articles.

# %%
df.mean(numeric_only=True)
# Out:
# word_count     120.27740
# text_length    810.95049
# dtype: float64

# %% [markdown]
# ## Median Values
#
# The median values provide a more representative measure of the central tendency of our data:
# - The median word count is around 72 words per article
# - The median text length is around 488 characters per article

# %%
df.median(numeric_only=True)
# Out:
# word_count      72.0
# text_length    488.0
# dtype: float64

# %% [markdown]
# ## Mode Values
#
# The mode values represent the most frequently occurring values in our data:
# - The most common word count is 4 words per article
# - The most common text length is 12 characters per article

# %%
df.mode(numeric_only=True)
# Out:
#    word_count  text_length
# 0           4           22

# %%
df[df['word_count'] < 5]
# Out:
#                                                 article_id  \
# 105      21_1938-10-16_p35_sn83045462_00280601858_19381...
# 106      24_1938-10-16_p35_sn83045462_00280601858_19381...
# 172      56_1938-08-02_p8_sn83045499_00393342353_193808...
# 173      57_1938-08-02_p8_sn83045499_00393342353_193808...
# 175      60_1938-08-02_p8_sn83045499_00393342353_193808...
# ...                                                    ...
# 4368496  88_1945-11-16_p1_sn82014085_00393346838_194511...
# 4368497  90_1945-11-16_p1_sn82014085_00393346838_194511...
# 4368498  91_1945-11-16_p1_sn82014085_00393346838_194511...
# 4368505  35_1945-02-25_p6_sn83045462_00280603843_194502...
# 4368686  81_1945-01-09_p2_sn82014085_00393346784_194501...
#
#                    newspaper_name edition        date page  \
# 105                 Evening star.      01  1938-10-16  p35
# 106                 Evening star.      01  1938-10-16  p35
# 172      The Daily Alaska empire.      01  1938-08-02   p8
# 173      The Daily Alaska empire.      01  1938-08-02   p8
# 175      The Daily Alaska empire.      01  1938-08-02   p8
# ...                           ...     ...         ...  ...
# 4368496   The Waterbury Democrat.      01  1945-11-16   p1
# 4368497   The Waterbury Democrat.      01  1945-11-16   p1
# 4368498   The Waterbury Democrat.      01  1945-11-16   p1
# 4368505             Evening star.      01  1945-02-25   p6
# 4368686   The Waterbury Democrat.      01  1945-01-09   p2
#
#                           headline byline                        article  \
# 105                                              (see HEALEY. Page C-3.)
# 106                                            (see EDGERToN, Page C-s0.
# 172                                          Today's News Today.-Empire.
# 173                                                    Try an Empire ad.
# 175                                              Empire classifieds pay.
# ...                            ...    ...                            ...
# 4368496                                              Continued on Page D
# 4368497                                            tcOntinued on Page ID
# 4368498                                              Continued on Page D
# 4368505                                    \n\ncapital\n\n\n\n\n\n\nNavy
# 4368686  Woterburions Not Selected                 Continued from Page D
#
#          word_count  text_length
# 105               4           23
# 106               4           25
# 172               3           27
# 173               4           17
# 175               3           23
# ...             ...          ...
# 4368496           4           19
# 4368497           4           21
# 4368498           4           19
# 4368505           1           20
# 4368686           4           21
#
# [72123 rows x 10 columns]

# %% [markdown]
# ## Standard Deviation
#
# The standard deviation measures the amount of variation or dispersion in our data:
# - The word count standard deviation is around 137 words
# - The text length standard deviation is around 930 characters

# %%
df.std(numeric_only=True)
# Out:
# word_count     137.986893
# text_length    930.291942
# dtype: float64

# %% [markdown]
# ## Minimum and Maximum Values
#
# The minimum and maximum values give us the smallest and largest values in our data:
# - The minimum word count is 1 words
# - The minimum text length is 1 characters
# - The maximum word count is 1920 words
# - The maximum text length is 8969 characters

# %%
df.min(numeric_only=True)
# Out:
# word_count     1
# text_length    1
# dtype: int32

# %%
df.max(numeric_only=True)
# Out:
# word_count     1920
# text_length    8969
# dtype: int32

# %% [markdown]
# ## Unique Values
#
# The number of unique values in our data:

# %%
df.nunique()
# Out:
# article_id        4368788
# newspaper_name         90
# edition                 2
# date                 2922
# page                  152
# headline          2284264
# byline             201573
# article           4304503
# word_count           1212
# text_length          7270
# dtype: int64

# %% [markdown]
# ## Cleaning DataFrame

# %%
df['article'].value_counts().head(50)
# Out:
# article
# Continued from Page D                                                                 2093
# (Continued from Page D                                                                1939
# Continued from Page One)                                                               710
# (Continued on Page 4)                                                                  670
# Continued on Page D                                                                    640
# (Continued on Page D                                                                   596
# Continued on Page 9                                                                    576
# Continued on Page A                                                                    575
# (Continued on Page 9                                                                   571
# (Continued on Page A                                                                   559
# Continued From First Page.)                                                            525
# (Continued from Page One)                                                              504
# Continued on Page 4)                                                                   500
# BUY DEFENSE STAMPS                                                                     486
# BUY DEFENSE BONDS                                                                      453
# ADVERTISEMENT                                                                          448
# Subscribe for The Empire.                                                              384
# Try an Empire ad.                                                                      375
# Empire Classifieds Pay!                                                                349
# Continued on Page Four)                                                                341
# ADJUSTMENTS.                                                                           325
# ADVERTISEMENT.                                                                         313
# Continued From First Page)                                                             311
# tcontinued from Page D                                                                 291
# Subscribe for The Nome Nugget                                                          286
# Continued on Page Three)                                                               266
# Continued on Page Five)                                                                262
# Can you answer seven of these test questions? Turn to last page for the answers.       258
# Continued on Page Two)                                                                 253
# tContinued from Page D                                                                 225
# (continued from Page D                                                                 223
# BUY WAR BONDS AND STAMPS                                                               218
# Lode and placer location notices for sale at The Empire Office.                        196
# Empire classifieds pay.                                                                189
# Continued from Page one)                                                               187
# The Daily Alaska Empire has the largest paid circulation of any AL aska newspaper.     185
# Good Night.                                                                            181
# Empire Want Ads Bring Results.                                                         174
# BUY WAR BONDS                                                                          172
# (Continued on Page 4                                                                   170
# (Continued on Page N                                                                   167
# Continued on Page 4                                                                    165
# Subscribe to the Daily Alaska Empire-the paper with the largest paid circulation.      160
# Try The Empire classifieds for results.                                                155
# Empire classifieds bring results.                                                      149
# Can you answer seven of these test questions? Turn to back page for the answers.       149
# (Continued from Page 1)                                                                147
# Try a classified ad in The Empire                                                      145
# PUBLIC UTILITY                                                                         142
# Continued on Page N                                                                    142
# Name: count, dtype: int64

# %%
# Get articles that appear more than 50 times
frequent_articles = df['article'].value_counts()[df['article'].value_counts() > 4].index

# Remove rows with those frequent articles
df = df[~df['article'].isin(frequent_articles)]
df
# Out:
#                                                 article_id  \
# 0        1_1938-11-08_p3_sn82014085_00393347429_1938110...
# 1        3_1938-11-08_p3_sn82014085_00393347429_1938110...
# 2        4_1938-11-08_p3_sn82014085_00393347429_1938110...
# 3        5_1938-11-08_p3_sn82014085_00393347429_1938110...
# 4        6_1938-11-08_p3_sn82014085_00393347429_1938110...
# ...                                                    ...
# 4368783  28_1945-12-05_p7_sn88063294_00340589130_194512...
# 4368784  10_1945-04-18_p35_sn83045462_00280604082_19450...
# 4368785  3_1945-04-18_p35_sn83045462_00280604082_194504...
# 4368786  21_1945-04-18_p35_sn83045462_00280604082_19450...
# 4368787  6_1945-04-18_p35_sn83045462_00280604082_194504...
#
#                   newspaper_name edition        date page  \
# 0        The Waterbury Democrat.      01  1938-11-08   p3
# 1        The Waterbury Democrat.      01  1938-11-08   p3
# 2        The Waterbury Democrat.      01  1938-11-08   p3
# 3        The Waterbury Democrat.      01  1938-11-08   p3
# 4        The Waterbury Democrat.      01  1938-11-08   p3
# ...                          ...     ...         ...  ...
# 4368783   Detroit evening times.      01  1945-12-05   p7
# 4368784            Evening star.      01  1945-04-18  p35
# 4368785            Evening star.      01  1945-04-18  p35
# 4368786            Evening star.      01  1945-04-18  p35
# 4368787            Evening star.      01  1945-04-18  p35
#
#                                                   headline  \
# 0         Fear Heavy Toll Among Civilians In Next Conflict
# 1
# 2        Audience Thrilled By\n\n Early Masters Works\n...
# 3        Democrats Institute Court Action T oday\n\n To...
# 4        q WOMEN SEEK\n\n ELECTION JOBS\n\nNone Candida...
# ...                                                    ...
# 4368783
# 4368784  ADVERTISEMENT,\n\nADNL n lSLhLt>1\nTorment OF ...
# 4368785  Jury Rules Chaplin\nIs.Father;; Conference\nOn...
# 4368786                          Use Your\nBeIdqet Account
# 4368787                              Verdict for Defendant
#
#                                                     byline  \
# 0
# 1
# 2
# 3
# 4        BY RUBY A. BLACK nifAd preea Sfaff Corresnovad...
# ...                                                    ...
# 4368783
# 4368784
# 4368785                           By the Associated Press.
# 4368786
# 4368787
#
#                                                    article  word_count  \
# 0        Recognition of a probable heavy toll among non...         233
# 1        Conforming to tradition, the Democratic candid...         256
# 2        second by Kasper Ferdinand Fisch- CT.\n\n FOlk...         124
# 3        in behalf of Charles Maloney of Se4 East Main ...         224
# 4        NUnlte0 freSS Stam COrreSpOn0ent)\n\n Washingt...         280
# ...                                                    ...         ...
# 4368783  Here's a contest you win! And what prize!\nA b...          51
# 4368784  II you can't get your feet of your mind\nbecau...          55
# 4368785  By the Associated Press.\n\n\nLOS ANGELES, Apr...         221
# 4368786  It's easy as A-B-C to open a\nCharge, Budget o...          23
# 4368787  A District Court jury yesterday\nreturned a ve...          52
#
#          text_length
# 0               1506
# 1               1624
# 2                766
# 3               1278
# 4               1746
# ...              ...
# 4368783          321
# 4368784          379
# 4368785         1616
# 4368786          142
# 4368787          387
#
# [4317293 rows x 10 columns]

# %%
df['article'].value_counts().head(5)
# Out:
# article
# Pacific Coast League                                                           4
# BROOM apartment, hot and cold water, steam heat, electric range. Phone 569.    4
# Want to make Hitler unhappy?\nBuy Defense stamps and bonds.                    4
# Let the race driver do the speeding\ndrive sanely.                             4
# (See CONGRESS, Page A-3)                                                       4
# Name: count, dtype: int64
